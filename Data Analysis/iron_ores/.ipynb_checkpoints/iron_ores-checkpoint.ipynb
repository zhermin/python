# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

dfs = pd.read_excel("iron_ores.xlsx", sheet_name=None, skiprows=[0,2,3,4,5,6,7], parse_dates=["指标名称"])
rizhao = dfs["Rizhao Port"]
#rizhao.head()

# %%
x = rizhao["指标名称"]
y = rizhao["61．5%PB粉品牌价格：日照港（日）"]
plt.scatter(x,y, marker=".", s=1)
# Out:
# c:\users\zm\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#plt.xlabel("Date")
#plt.ylabel("Price")
#plt.xlabel("61.5% PB")
rizhao.boxplot(column=["61．5%PB粉品牌价格：日照港（日）"], showmeans=True, grid=False)

# %%
sns.boxplot(x=rizhao_61pb, data=rizhao, width=0.1, palette="husl", orient="v", showmeans=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3b19dd23e083> in <module>
# ----> 1 sns.boxplot(x=rizhao_61pb, data=rizhao, width=0.1, palette="husl", orient="v", showmeans=True)
#
# NameError: name 'rizhao_61pb' is not defined

# %%
tianjin = dfs["Tianjin Port"]
#tianjin.head()

qingdao = dfs["Qingdao Port"]

# %%
for i in range(len(tianjin.columns)-1):
    tianjinindex = tianjin.iloc[:, i+1]
    sns.boxplot(x=tianjinindex, data=tianjinindex, width=0.1, palette="husl", orient="v", showmeans=True, showfliers=False)

# %%
for i in range(len(tianjin.columns)-1):
    tianjinindex = tianjin.iloc[:, i+1]
    sns.boxplot(x=tianjinindex, data=tianjinindex, width=0.1, palette="husl", orient="v", showmeans=True, showfliers=True)

# %%
tianjinindex = tianjin.iloc[:, 18]
sns.boxplot(x=tianjinindex, data=tianjinindex, width=0.1, palette="husl", orient="v", showmeans=True, showfliers=True)

# %%
plt.rcParams['figure.figsize'] = [20, 8]

for i in range(1,21):
    plt.xlabel("Date")
    plt.ylabel(f"Graph {i}")

    dates = tianjin.iloc[:, 0]

    tianjin_y = tianjin.iloc[:, i]
    plt.scatter(dates,tianjin_y, marker="x", s=1, color="blue", label="TianJin Port")
    #plt.plot(dates, tianjin_y, color="blue", label="TianJin Port")

    # tjy18 = tianjin.iloc[:, 18]
    # plt.scatter(dates,tjy18, marker=".", s=1, color="red")

    rizhao_y = tianjin.iloc[:, i]
    plt.scatter(dates,rizhao_y, marker="+", s=1, color="red", label="RiZhao Port")
    #plt.plot(dates, tianjin_y, color="red", label="Rizhao Port", linewidth=0.5)

    plt.legend()
    plt.show()
    #plt.cla()
